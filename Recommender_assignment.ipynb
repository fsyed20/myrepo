# %%
import pandas as pd
import numpy as np

# %%
M = pd.read_csv("movies.csv", index_col='Name')

# %%
M
# Out:
#                          American Sniper  \
# Name
# Mike                                 NaN
# HJ SONG                              NaN
# Ryan Hansen                          NaN
# Olumuyiwa Durojaiye                  NaN
# Charlie                              NaN
# Sina Tuy                             NaN
# Pavithra Shetty                      NaN
# Sara Collins                         NaN
# Jonathan Doll                        NaN
# saikiran reddy                         3
# Aishwarya reddy                      NaN
# Brant Mullinix                       NaN
# Sai Sampath                          NaN
# Suyendra                             NaN
# Sai Yallapragada                       5
# Akhilesh                             NaN
# Sundar Prasad                        NaN
# Evan Piercy                            4
# Jessica Fong                         NaN
# Onsiri Tapsarn                         3
# Anirudh Thota                        NaN
# Greg Werner                            5
# ...

# %%
def pearson(s1, s2):
    s1_c = s1 - s1.mean()
    s2_c = s2 - s2.mean()
    return np.sum(s1_c * s2_c) / np.sqrt(np.sum(s1_c ** 2) * np.sum(s2_c ** 2))

# %%
def get_recs(movie_name, M, num):

    import numpy as np
    reviews = []
    for title in M.columns:
        if title == movie_name:
            continue
        cor = pearson(M[movie_name], M[title])
        if np.isnan(cor):
            continue
        else:
            reviews.append((title, cor))
    
    reviews.sort(key=lambda tup: tup[1], reverse=True)
    return reviews[:num]

# %% [markdown]
# ###Question 1:  What movie is most Similar to 'The fault in our stars'

# %%
 get_recs('The Fault in Our Stars', M, 1)
# Out:
# [('How to Train your Dragon 2', 0.3391851271314606)]

# %% [markdown]
# ###Question 2:  Which movie(s) would you most like to see, based on your classmates experience?

# %%
my_ratings = M.ix['Syed Farzan'].dropna()

# %%
my_ratings.sort(ascending=False)

# %% [markdown]
# ### 1.

# %%
fav_movie = my_ratings.index[0]

# %%
fav_movie
# Out:
# 'Interstellar'

# %%
fav1=  get_recs('Interstellar', M, 3)

# %%
fav1[:3]
# Out:
# [('Divergent', 0.26384088921036219),
#  ('Transformers', 0.18038930075225304),
#  ('The Hobbit', 0.17506171891526198)]

# %% [markdown]
# ### 2.

# %%
fav_movie = my_ratings.index[1]

# %%
fav_movie
# Out:
# 'The Hobbit'

# %%
fav2= get_recs('The Hobbit',M,3)

# %%
fav2[:3]
# Out:
# [('How to Train your Dragon 2', 0.25536202607663677),
#  ('Malificent', 0.22453208748559841),
#  ('Interstellar', 0.17506171891526198)]

# %% [markdown]
# ### 3.

# %%
fav_movie = my_ratings.index[2]

# %%
fav_movie
# Out:
# '300: Rise of an Empire'

# %%
fav3= get_recs('300: Rise of an Empire',M,3)

# %%
fav3[:3]
# Out:
# [('American Sniper', 0.34367727491213496),
#  ('Gone Girl', 0.23542114618194646),
#  ('Divergent', 0.13353903129678429)]

# %% [markdown]
# ### Question 3: Bonus Question...  For all the movies you haven't seen, can you predict how you'd rate them using your  class reviews?

# %%
M.ix['Syed Farzan'].isnull()
# Out:
# American Sniper                           True
# The Hunger Games: Mockingjay - Part 1    False
# Guardians of the Galaxy                   True
# The Lego Movie                            True
# The Hobbit                               False
# Transformers                             False
# Malificent                                True
# Big Hero 6                                True
# Godzilla                                 False
# Interstellar                             False
# How to Train your Dragon 2               False
# Gone Girl                                 True
# Divergent                                 True
# The Fault in Our Stars                    True
# Unbroken                                  True
# 300: Rise of an Empire                   False
# Name: Syed Farzan, dtype: bool

# %%
#  American Sniper
get_recs('American Sniper',M,3)
# Out:
# [('Gone Girl', 0.46030845717781688),
#  ('300: Rise of an Empire', 0.34367727491213496),
#  ('The Lego Movie', 0.18250538094492905)]

# %%
M.ix['Syed Farzan']['300: Rise of an Empire']
# Out:
# 3.0

# %%
# I would rate this movie,'The Lego Movie 3 and 'Gone Girl' 3

# %%
#  Guardians of the Galaxy
get_recs('Guardians of the Galaxy',M,3)
# Out:
# [('The Lego Movie', 0.48594092929113747),
#  ('The Hunger Games: Mockingjay - Part 1', 0.35093422465405871),
#  ('Godzilla', 0.2597197532763767)]

# %%
M.ix['Syed Farzan']['The Hunger Games: Mockingjay - Part 1']
# Out:
# 3.0

# %%
# I would rate this movie 3

# %%
# Malificent
get_recs('Malificent', M,3)
# Out:
# [('Big Hero 6', 0.30635042439773619),
#  ('The Fault in Our Stars', 0.29570570162416671),
#  ('Godzilla', 0.25947019268013211)]

# %%
M.ix['Syed Farzan']['Godzilla']
# Out:
# 3.0

# %%
# I would rate this movie, 'Big Hero 6' and 'The Fault in our stars' 3

# %%
get_recs('Divergent',M,3)
# Out:
# [('How to Train your Dragon 2', 0.28135986115023887),
#  ('Interstellar', 0.26384088921036219),
#  ('The Hunger Games: Mockingjay - Part 1', 0.20852022158973815)]

# %%
M.ix['Syed Farzan']['How to Train your Dragon 2']
# Out:
# 3.0

# %%
# I would rate this movie 3

# %%
get_recs('Unbroken',M,3)
# Out:
# [('Big Hero 6', 0.28996370008747813),
#  ('Transformers', 0.2071567895421568),
#  ('Malificent', 0.12974212083211939)]

# %%
M.ix['Syed Farzan']['Transformers']
# Out:
# 3.0

# %%
# I would rate this movie 3
